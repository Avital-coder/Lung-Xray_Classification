# %%
import numpy as np
from numpy import asarray
import tensorflow as tf
import os
from keras.utils import load_img
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array
import re
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def extract_number(text):
    match = re.search(r'\d+', text)
    if match:
        number = int(match.group())
        return number
    else:
        raise ValueError("No number found in the text")

# %%
def run_model(dir_path):
    data_folder = dir_path
    alloed_image_formats = ('.jpeg', '.jpg', '.png')
    images, labels = [], []

    # Load data from directory path
    for subfolder in os.listdir(data_folder):
        subfolder_path = os.path.join(data_folder, subfolder) # data/{01 or 02 or 03}

        if os.path.isdir(subfolder_path):
            label = extract_number(subfolder)

            for file_name in os.listdir(subfolder_path):
                file_path = os.path.join(subfolder_path, file_name)

                try:
                    if file_path.lower().endswith(alloed_image_formats):
                        image = load_img(file_path, target_size=(224, 224))
                        image_as_array = asarray(image)

                        images.append(image_as_array)
                        labels.append(label)
                except:
                    print('Can\'t load', file_path)
                    continue

    images = asarray(images)
    labels = asarray(labels)

    # Global Normalization - Scaling it to gray colors because we dont benefit from RGB
    images = np.array([img_to_array(img) for img in images]) / 255.0
    labels = np.array(labels)

    # Individual Normalization
    normalized_images = []
    for image in images:
        norm_image = (image - np.min(image)) / (np.max(image) - np.min(image))
        normalized_images.append(norm_image)
    normalized_images = np.array(normalized_images)

    images = normalized_images
    NUM_CLASSES = 3

    # Encode y labels
    labels_encoded = to_categorical(labels -1, NUM_CLASSES)

    # Load the model
    inception_model_loaded = load_model('inception_model.keras')

    # Predict classs on the data
    predictions = inception_model_loaded.predict(images)
    preds_classes = np.argmax(predictions, axis=1)
    preds_classes= preds_classes + 1

    for i in range(len(images)):
        print('Image number: ', i, ', Predicted: ', preds_classes[i], ', Origin: ', labels[i])

    # Evaluate the model on the data
    inception_results_loaded = inception_model_loaded.evaluate(images, labels_encoded)
    print('Model accuracy:', inception_results_loaded[1])

    cm = confusion_matrix(labels, preds_classes)
    print('Confusion matrix', '\n', cm)

# %%
path = input('Please enter your path:')
run_model(path)
# Out:
# Please enter your path:/content/drive/MyDrive/medical-imaging-project/data
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 38s 4s/step
# Image number:  0 , Predicted:  3 , Origin:  3
# Image number:  1 , Predicted:  3 , Origin:  3
# Image number:  2 , Predicted:  3 , Origin:  3
# Image number:  3 , Predicted:  3 , Origin:  3
# Image number:  4 , Predicted:  3 , Origin:  3
# Image number:  5 , Predicted:  3 , Origin:  3
# Image number:  6 , Predicted:  3 , Origin:  3
# Image number:  7 , Predicted:  3 , Origin:  3
# Image number:  8 , Predicted:  3 , Origin:  3
# Image number:  9 , Predicted:  3 , Origin:  3
# Image number:  10 , Predicted:  3 , Origin:  3
# Image number:  11 , Predicted:  3 , Origin:  3
# Image number:  12 , Predicted:  3 , Origin:  3
# Image number:  13 , Predicted:  3 , Origin:  3
# Image number:  14 , Predicted:  3 , Origin:  3
# Image number:  15 , Predicted:  3 , Origin:  3
# Image number:  16 , Predicted:  3 , Origin:  3
# Image number:  17 , Predicted:  3 , Origin:  3
# Image number:  18 , Predicted:  3 , Origin:  3
# Image number:  19 , Predicted:  3 , Origin:  3
# Image number:  20 , Predicted:  3 , Origin:  3
# Image number:  21 , Predicted:  3 , Origin:  3
# Image number:  22 , Predicted:  3 , Origin:  3
# Image number:  23 , Predicted:  3 , Origin:  3
# Image number:  24 , Predicted:  3 , Origin:  3
# Image number:  25 , Predicted:  3 , Origin:  3
# Image number:  26 , Predicted:  3 , Origin:  3
# Image number:  27 , Predicted:  3 , Origin:  3
# Image number:  28 , Predicted:  3 , Origin:  3
# Image number:  29 , Predicted:  3 , Origin:  3
# Image number:  30 , Predicted:  3 , Origin:  3
# Image number:  31 , Predicted:  3 , Origin:  3
# Image number:  32 , Predicted:  3 , Origin:  3
# Image number:  33 , Predicted:  3 , Origin:  3
# Image number:  34 , Predicted:  3 , Origin:  3
# Image number:  35 , Predicted:  3 , Origin:  3
# Image number:  36 , Predicted:  3 , Origin:  3
# Image number:  37 , Predicted:  3 , Origin:  3
# Image number:  38 , Predicted:  3 , Origin:  3
# Image number:  39 , Predicted:  3 , Origin:  3
# Image number:  40 , Predicted:  3 , Origin:  3
# Image number:  41 , Predicted:  3 , Origin:  3
# Image number:  42 , Predicted:  3 , Origin:  3
# Image number:  43 , Predicted:  3 , Origin:  3
# Image number:  44 , Predicted:  3 , Origin:  3
# Image number:  45 , Predicted:  3 , Origin:  3
# Image number:  46 , Predicted:  3 , Origin:  3
# Image number:  47 , Predicted:  3 , Origin:  3
# Image number:  48 , Predicted:  3 , Origin:  3
# Image number:  49 , Predicted:  3 , Origin:  3
# Image number:  50 , Predicted:  3 , Origin:  3
# Image number:  51 , Predicted:  3 , Origin:  3
# Image number:  52 , Predicted:  3 , Origin:  3
# Image number:  53 , Predicted:  3 , Origin:  3
# Image number:  54 , Predicted:  3 , Origin:  3
# Image number:  55 , Predicted:  3 , Origin:  3
# Image number:  56 , Predicted:  3 , Origin:  3
# Image number:  57 , Predicted:  3 , Origin:  3
# Image number:  58 , Predicted:  3 , Origin:  3
# Image number:  59 , Predicted:  3 , Origin:  3
# Image number:  60 , Predicted:  3 , Origin:  3
# Image number:  61 , Predicted:  3 , Origin:  3
# Image number:  62 , Predicted:  3 , Origin:  3
# Image number:  63 , Predicted:  1 , Origin:  3
# Image number:  64 , Predicted:  3 , Origin:  3
# Image number:  65 , Predicted:  3 , Origin:  3
# Image number:  66 , Predicted:  3 , Origin:  3
# Image number:  67 , Predicted:  3 , Origin:  3
# Image number:  68 , Predicted:  3 , Origin:  3
# Image number:  69 , Predicted:  3 , Origin:  3
# Image number:  70 , Predicted:  3 , Origin:  3
# Image number:  71 , Predicted:  3 , Origin:  3
# Image number:  72 , Predicted:  3 , Origin:  3
# Image number:  73 , Predicted:  3 , Origin:  3
# Image number:  74 , Predicted:  3 , Origin:  3
# Image number:  75 , Predicted:  3 , Origin:  3
# Image number:  76 , Predicted:  3 , Origin:  3
# Image number:  77 , Predicted:  3 , Origin:  3
# Image number:  78 , Predicted:  3 , Origin:  3
# Image number:  79 , Predicted:  3 , Origin:  3
# Image number:  80 , Predicted:  3 , Origin:  3
# Image number:  81 , Predicted:  3 , Origin:  3
# Image number:  82 , Predicted:  3 , Origin:  3
# Image number:  83 , Predicted:  3 , Origin:  3
# Image number:  84 , Predicted:  3 , Origin:  3
# Image number:  85 , Predicted:  3 , Origin:  3
# Image number:  86 , Predicted:  3 , Origin:  3
# Image number:  87 , Predicted:  3 , Origin:  3
# Image number:  88 , Predicted:  3 , Origin:  3
# Image number:  89 , Predicted:  3 , Origin:  3
# Image number:  90 , Predicted:  3 , Origin:  3
# Image number:  91 , Predicted:  3 , Origin:  3
# Image number:  92 , Predicted:  3 , Origin:  3
# Image number:  93 , Predicted:  3 , Origin:  3
# Image number:  94 , Predicted:  3 , Origin:  3
# Image number:  95 , Predicted:  3 , Origin:  3
# Image number:  96 , Predicted:  3 , Origin:  3
# Image number:  97 , Predicted:  3 , Origin:  3
# Image number:  98 , Predicted:  3 , Origin:  3
# Image number:  99 , Predicted:  3 , Origin:  3
# Image number:  100 , Predicted:  3 , Origin:  3
# Image number:  101 , Predicted:  3 , Origin:  3
# Image number:  102 , Predicted:  3 , Origin:  3
# Image number:  103 , Predicted:  3 , Origin:  3
# Image number:  104 , Predicted:  3 , Origin:  3
# Image number:  105 , Predicted:  3 , Origin:  3
# Image number:  106 , Predicted:  3 , Origin:  3
# Image number:  107 , Predicted:  3 , Origin:  3
# Image number:  108 , Predicted:  3 , Origin:  3
# Image number:  109 , Predicted:  3 , Origin:  3
# Image number:  110 , Predicted:  3 , Origin:  3
# Image number:  111 , Predicted:  1 , Origin:  1
# Image number:  112 , Predicted:  1 , Origin:  1
# Image number:  113 , Predicted:  1 , Origin:  1
# Image number:  114 , Predicted:  1 , Origin:  1
# Image number:  115 , Predicted:  1 , Origin:  1
# Image number:  116 , Predicted:  1 , Origin:  1
# Image number:  117 , Predicted:  1 , Origin:  1
# Image number:  118 , Predicted:  1 , Origin:  1
# Image number:  119 , Predicted:  1 , Origin:  1
# Image number:  120 , Predicted:  1 , Origin:  1
# Image number:  121 , Predicted:  1 , Origin:  1
# Image number:  122 , Predicted:  1 , Origin:  1
# Image number:  123 , Predicted:  1 , Origin:  1
# Image number:  124 , Predicted:  2 , Origin:  1
# Image number:  125 , Predicted:  1 , Origin:  1
# Image number:  126 , Predicted:  1 , Origin:  1
# Image number:  127 , Predicted:  1 , Origin:  1
# Image number:  128 , Predicted:  1 , Origin:  1
# Image number:  129 , Predicted:  1 , Origin:  1
# Image number:  130 , Predicted:  1 , Origin:  1
# Image number:  131 , Predicted:  1 , Origin:  1
# Image number:  132 , Predicted:  1 , Origin:  1
# Image number:  133 , Predicted:  1 , Origin:  1
# Image number:  134 , Predicted:  1 , Origin:  1
# Image number:  135 , Predicted:  1 , Origin:  1
# Image number:  136 , Predicted:  1 , Origin:  1
# Image number:  137 , Predicted:  1 , Origin:  1
# Image number:  138 , Predicted:  1 , Origin:  1
# Image number:  139 , Predicted:  1 , Origin:  1
# Image number:  140 , Predicted:  1 , Origin:  1
# Image number:  141 , Predicted:  1 , Origin:  1
# Image number:  142 , Predicted:  1 , Origin:  1
# Image number:  143 , Predicted:  1 , Origin:  1
# Image number:  144 , Predicted:  1 , Origin:  1
# Image number:  145 , Predicted:  1 , Origin:  1
# Image number:  146 , Predicted:  1 , Origin:  1
# Image number:  147 , Predicted:  1 , Origin:  1
# Image number:  148 , Predicted:  1 , Origin:  1
# Image number:  149 , Predicted:  1 , Origin:  1
# Image number:  150 , Predicted:  1 , Origin:  1
# Image number:  151 , Predicted:  1 , Origin:  1
# Image number:  152 , Predicted:  1 , Origin:  1
# Image number:  153 , Predicted:  1 , Origin:  1
# Image number:  154 , Predicted:  1 , Origin:  1
# Image number:  155 , Predicted:  1 , Origin:  1
# Image number:  156 , Predicted:  1 , Origin:  1
# Image number:  157 , Predicted:  1 , Origin:  1
# Image number:  158 , Predicted:  1 , Origin:  1
# Image number:  159 , Predicted:  1 , Origin:  1
# Image number:  160 , Predicted:  1 , Origin:  1
# Image number:  161 , Predicted:  1 , Origin:  1
# Image number:  162 , Predicted:  1 , Origin:  1
# Image number:  163 , Predicted:  1 , Origin:  1
# Image number:  164 , Predicted:  1 , Origin:  1
# Image number:  165 , Predicted:  1 , Origin:  1
# Image number:  166 , Predicted:  1 , Origin:  1
# Image number:  167 , Predicted:  1 , Origin:  1
# Image number:  168 , Predicted:  1 , Origin:  1
# Image number:  169 , Predicted:  1 , Origin:  1
# Image number:  170 , Predicted:  1 , Origin:  1
# Image number:  171 , Predicted:  1 , Origin:  1
# Image number:  172 , Predicted:  1 , Origin:  1
# Image number:  173 , Predicted:  1 , Origin:  1
# Image number:  174 , Predicted:  1 , Origin:  1
# Image number:  175 , Predicted:  1 , Origin:  1
# Image number:  176 , Predicted:  1 , Origin:  1
# Image number:  177 , Predicted:  1 , Origin:  1
# Image number:  178 , Predicted:  1 , Origin:  1
# Image number:  179 , Predicted:  1 , Origin:  1
# Image number:  180 , Predicted:  1 , Origin:  1
# Image number:  181 , Predicted:  2 , Origin:  2
# Image number:  182 , Predicted:  2 , Origin:  2
# Image number:  183 , Predicted:  2 , Origin:  2
# Image number:  184 , Predicted:  2 , Origin:  2
# Image number:  185 , Predicted:  2 , Origin:  2
# Image number:  186 , Predicted:  2 , Origin:  2
# Image number:  187 , Predicted:  2 , Origin:  2
# Image number:  188 , Predicted:  2 , Origin:  2
# Image number:  189 , Predicted:  2 , Origin:  2
# Image number:  190 , Predicted:  2 , Origin:  2
# Image number:  191 , Predicted:  2 , Origin:  2
# Image number:  192 , Predicted:  2 , Origin:  2
# Image number:  193 , Predicted:  2 , Origin:  2
# Image number:  194 , Predicted:  2 , Origin:  2
# Image number:  195 , Predicted:  2 , Origin:  2
# Image number:  196 , Predicted:  2 , Origin:  2
# Image number:  197 , Predicted:  2 , Origin:  2
# Image number:  198 , Predicted:  2 , Origin:  2
# Image number:  199 , Predicted:  2 , Origin:  2
# Image number:  200 , Predicted:  2 , Origin:  2
# Image number:  201 , Predicted:  2 , Origin:  2
# Image number:  202 , Predicted:  2 , Origin:  2
# Image number:  203 , Predicted:  2 , Origin:  2
# Image number:  204 , Predicted:  2 , Origin:  2
# Image number:  205 , Predicted:  1 , Origin:  2
# Image number:  206 , Predicted:  2 , Origin:  2
# Image number:  207 , Predicted:  2 , Origin:  2
# Image number:  208 , Predicted:  2 , Origin:  2
# Image number:  209 , Predicted:  2 , Origin:  2
# Image number:  210 , Predicted:  2 , Origin:  2
# Image number:  211 , Predicted:  2 , Origin:  2
# Image number:  212 , Predicted:  2 , Origin:  2
# Image number:  213 , Predicted:  2 , Origin:  2
# Image number:  214 , Predicted:  2 , Origin:  2
# Image number:  215 , Predicted:  1 , Origin:  2
# Image number:  216 , Predicted:  2 , Origin:  2
# Image number:  217 , Predicted:  2 , Origin:  2
# Image number:  218 , Predicted:  2 , Origin:  2
# Image number:  219 , Predicted:  2 , Origin:  2
# Image number:  220 , Predicted:  2 , Origin:  2
# Image number:  221 , Predicted:  2 , Origin:  2
# Image number:  222 , Predicted:  2 , Origin:  2
# Image number:  223 , Predicted:  2 , Origin:  2
# Image number:  224 , Predicted:  1 , Origin:  2
# Image number:  225 , Predicted:  2 , Origin:  2
# Image number:  226 , Predicted:  2 , Origin:  2
# Image number:  227 , Predicted:  2 , Origin:  2
# Image number:  228 , Predicted:  2 , Origin:  2
# Image number:  229 , Predicted:  2 , Origin:  2
# Image number:  230 , Predicted:  2 , Origin:  2
# Image number:  231 , Predicted:  2 , Origin:  2
# Image number:  232 , Predicted:  2 , Origin:  2
# Image number:  233 , Predicted:  2 , Origin:  2
# Image number:  234 , Predicted:  2 , Origin:  2
# Image number:  235 , Predicted:  2 , Origin:  2
# Image number:  236 , Predicted:  2 , Origin:  2
# Image number:  237 , Predicted:  2 , Origin:  2
# Image number:  238 , Predicted:  2 , Origin:  2
# Image number:  239 , Predicted:  2 , Origin:  2
# Image number:  240 , Predicted:  2 , Origin:  2
# Image number:  241 , Predicted:  2 , Origin:  2
# Image number:  242 , Predicted:  2 , Origin:  2
# Image number:  243 , Predicted:  2 , Origin:  2
# Image number:  244 , Predicted:  2 , Origin:  2
# Image number:  245 , Predicted:  2 , Origin:  2
# Image number:  246 , Predicted:  2 , Origin:  2
# Image number:  247 , Predicted:  2 , Origin:  2
# Image number:  248 , Predicted:  2 , Origin:  2
# Image number:  249 , Predicted:  2 , Origin:  2
# Image number:  250 , Predicted:  1 , Origin:  2
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 33s 4s/step - accuracy: 0.9855 - loss: 0.2068
# Model accuracy: 0.9760956168174744
# Confusion matrix
#  [[ 69   1   0]
#  [  4  66   0]
#  [  1   0 110]]
